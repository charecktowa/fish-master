# %%
import pandas as pd 
import numpy as np

# %%
# Especies que aparecen en los vídeos

fishes_list = [
    "Aglaophenia",
    "Aplysina aerophoba",
    "Chondrosia reniformis",
    "Cliona celata",
    "Coscinasterias tenuispina",
    "Crambe crambe",
    "Didemnum sp",
    "Dysidea_fragilis",
    "Eudendrium",
    "Ircinia variabilis",
    "Pecten jacobaeus",
    "Reptadeonella violacea",
    "Schizobrachiella sanguinea",
    "Arbacia lixula",
    "Caloria quatrefagesi",
    "Conger conger",
    "Cratena peregrina",
    "Flabellina affinis",
    "Gobius cruentatus",
    "Hexaplex trunculus",
    "Nemesignis banyulensis",
    "Parablennius gattorugine",
    "Parablennius pilicornis",
    "Parablennius tentacularis",
    "Polycera quadrilineata",
    "Serranus cabrilla",
    "Stenopus spinosus",
    "Stramonita haemastoma",
]

fishes_list = [x.lower().replace("_", " ").replace("-", " ") for x in fishes_list]
fishes_list
# Out:
# ['aglaophenia',
#  'aplysina aerophoba',
#  'chondrosia reniformis',
#  'cliona celata',
#  'coscinasterias tenuispina',
#  'crambe crambe',
#  'didemnum sp',
#  'dysidea fragilis',
#  'eudendrium',
#  'ircinia variabilis',
#  'pecten jacobaeus',
#  'reptadeonella violacea',
#  'schizobrachiella sanguinea',
#  'arbacia lixula',
#  'caloria quatrefagesi',
#  'conger conger',
#  'cratena peregrina',
#  'flabellina affinis',
#  'gobius cruentatus',
#  'hexaplex trunculus',
#  'nemesignis banyulensis',
#  'parablennius gattorugine',
#  'parablennius pilicornis',
#  'parablennius tentacularis',
#  'polycera quadrilineata',
#  'serranus cabrilla',
#  'stenopus spinosus',
#  'stramonita haemastoma']

# %%
df_1 = pd.read_csv("observations-416.csv", low_memory=False)
df_1.head(2)
# Out:
#     id observed_on_string observed_on time_observed_at time_zone  user_id  \
# 0  349         2021-04-30  2021-04-30              NaN    Madrid        4
# 1  350         2021-05-02  2021-05-02              NaN    Madrid        4
#
#   user_login            user_name               created_at  \
# 0    xasalva  xavi salvador costa  2022-04-16 10:48:58 UTC
# 1    xasalva  xavi salvador costa  2022-04-16 10:48:59 UTC
#
#                 updated_at  ... geoprivacy taxon_geoprivacy  \
# 0  2023-12-21 15:28:05 UTC  ...        NaN              NaN
# 1  2023-12-21 15:28:05 UTC  ...        NaN              NaN
#
#   coordinates_obscured positioning_method  positioning_device  \
# 0                False                NaN                 NaN
# 1                False                NaN                 NaN
#
#              species_guess          scientific_name  common_name  \
# 0  Spirobranchus triqueter  Spirobranchus triqueter          NaN
# 1        Eriphia verrucosa        Eriphia verrucosa          NaN
#
#    iconic_taxon_name  taxon_id
# 0           Annelida    251212
# 1       Malacostraca     35010
#
# [2 rows x 39 columns]

# %%
df_2 = pd.read_csv("observations-417.csv", low_memory=False)
df_2.head(2)
# Out:
#     id   observed_on_string observed_on         time_observed_at time_zone  \
# 0  345  2021-08-07 07:28:09  2021-08-07  2021-08-07 05:28:09 UTC    Madrid
# 1  346  2021-08-14 20:03:38  2021-08-14  2021-08-14 18:03:38 UTC    Madrid
#
#    user_id user_login            user_name               created_at  \
# 0        4    xasalva  xavi salvador costa  2022-04-16 10:48:53 UTC
# 1        4    xasalva  xavi salvador costa  2022-04-16 10:48:54 UTC
#
#                 updated_at  ... geoprivacy taxon_geoprivacy  \
# 0  2023-12-21 15:28:05 UTC  ...        NaN              NaN
# 1  2023-12-21 15:28:05 UTC  ...        NaN              NaN
#
#   coordinates_obscured positioning_method  positioning_device  \
# 0                False                NaN                 NaN
# 1                False                NaN                 NaN
#
#         species_guess     scientific_name  common_name  iconic_taxon_name  \
# 0     Elysia gordanae     Elysia gordanae          NaN           Mollusca
# 1  Placida cremoniana  Placida cremoniana          NaN           Mollusca
#
#    taxon_id
# 0    261646
# 1     35057
#
# [2 rows x 39 columns]

# %%
# Unir los dos dataframes
df = pd.concat([df_1, df_2], ignore_index=True)
df.head(3)
# Out:
#     id   observed_on_string observed_on         time_observed_at time_zone  \
# 0  349           2021-04-30  2021-04-30                      NaN    Madrid
# 1  350           2021-05-02  2021-05-02                      NaN    Madrid
# 2  352  2021-08-30 09:39:15  2021-08-30  2021-08-30 07:39:15 UTC    Madrid
#
#    user_id user_login            user_name               created_at  \
# 0        4    xasalva  xavi salvador costa  2022-04-16 10:48:58 UTC
# 1        4    xasalva  xavi salvador costa  2022-04-16 10:48:59 UTC
# 2        4    xasalva  xavi salvador costa  2022-04-16 10:49:00 UTC
#
#                 updated_at  ... geoprivacy taxon_geoprivacy  \
# 0  2023-12-21 15:28:05 UTC  ...        NaN              NaN
# 1  2023-12-21 15:28:05 UTC  ...        NaN              NaN
# 2  2023-12-21 15:28:05 UTC  ...        NaN              NaN
#
#   coordinates_obscured positioning_method  positioning_device  \
# 0                False                NaN                 NaN
# 1                False                NaN                 NaN
# 2                False                NaN                 NaN
#
#               species_guess           scientific_name  common_name  \
# 0   Spirobranchus triqueter   Spirobranchus triqueter          NaN
# 1         Eriphia verrucosa         Eriphia verrucosa          NaN
# 2  Sarcotragus fasciculatus  Sarcotragus fasciculatus          NaN
#
#    iconic_taxon_name  taxon_id
# 0           Annelida    251212
# 1       Malacostraca     35010
# 2           Porifera     34987
#
# [3 rows x 39 columns]

# %%
# Quitar las columnas que no se van a usar
columnas = [
    "observed_on_string",
    "observed_on",
    "time_observed_at",
    "time_zone",
    "user_id",
    "user_login",
    "user_name",
    "created_at",
    "updated_at",
    "quality_grade",
    "license",
    "url",
    "sound_url",
    "tag_list",
    "description",
    "num_identification_agreements",
    "num_identification_disagreements",
    "captive_cultivated",
    "oauth_application_id",
    "place_guess",
    "latitude",
    "longitude",
    "positional_accuracy",
    "private_place_guess",
    "private_latitude",
    "private_longitude",
    "public_positional_accuracy",
    "geoprivacy",
    "taxon_geoprivacy",
    "coordinates_obscured",
    "positioning_method",
    "positioning_device",
]

df = df.drop(columns=columnas)
df.reset_index(drop=True, inplace=True)
df.head(3)
# Out:
#     id                                          image_url  \
# 0  349  https://minka-sdg.org/attachments/local_photos...
# 1  350  https://minka-sdg.org/attachments/local_photos...
# 2  352  https://minka-sdg.org/attachments/local_photos...
#
#               species_guess           scientific_name common_name  \
# 0   Spirobranchus triqueter   Spirobranchus triqueter         NaN
# 1         Eriphia verrucosa         Eriphia verrucosa         NaN
# 2  Sarcotragus fasciculatus  Sarcotragus fasciculatus         NaN
#
#   iconic_taxon_name  taxon_id
# 0          Annelida    251212
# 1      Malacostraca     35010
# 2          Porifera     34987

# %%
# Count total number of instances in the dataset
total_instances = len(df)
print(f"El dataset contiene {total_instances} observaciones en total.")
# Out:
# El dataset contiene 248181 observaciones en total.

# %%
import re

import matplotlib.pyplot as plt

# Limpieza y estandarización de los nombres científicos
df['cleaned_name'] = df['scientific_name'].fillna('Desconocido')
df['cleaned_name'] = df['cleaned_name'].str.lower().str.strip()
df['cleaned_name'] = df['cleaned_name'].apply(lambda x: re.sub(r'[_\-]', ' ', x))

# Contar ocurrencias de cada especie
species_counts = df['cleaned_name'].value_counts()

# Crear gráfico
plt.figure(figsize=(15, 10))
species_counts.head(20).plot(kind='bar', color='skyblue')
plt.title('Número de Imágenes por Especie (Top 20)')
plt.xlabel('Nombre Científico')
plt.ylabel('Cantidad')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# Mostrar el número total de especies
print(f"Número total de especies distintas: {len(species_counts)}")
# Out:
# Número total de especies distintas: 3517

# %%
# Buscar especies de fishes_list en el dataframe
found_species = []
not_found_species = []
species_image_counts = {}

for species in fishes_list:
    species_parts = species.split()

    if len(species_parts) == 1:  # Solo género
        # Buscar cualquier especie de este género
        count = df[df["cleaned_name"].str.startswith(species + " ")].shape[0]
        # También buscar coincidencias exactas (por si es una especie sin nombre específico)
        exact_match = df[df["cleaned_name"] == species].shape[0]
        count += exact_match
    else:  # Nombre completo de especie
        # Buscar esta especie específica
        count = df[df["cleaned_name"] == species].shape[0]

    if count > 0:
        found_species.append(species)
        species_image_counts[species] = count
    else:
        not_found_species.append(species)

# Crear mensaje mostrando las especies encontradas
if found_species:
    print(f"Se encontraron {len(found_species)} especies de la lista en el dataset:")
    for species in found_species:
        print(f"- {species}: {species_image_counts[species]} imágenes")
else:
    print("No se encontró ninguna especie de la lista en el dataset.")

if not_found_species:
    print(f"\nNo se encontraron {len(not_found_species)} especies de la lista:")
    for species in not_found_species:
        print(f"- {species}")

# Crear DataFrame para la visualización
species_counts_df = pd.Series(species_image_counts).sort_values(ascending=False)

# Crear histograma
plt.figure(figsize=(15, 8))
species_counts_df.plot(kind="bar", color="skyblue")
plt.title("Número de Imágenes por Especie (de la lista proporcionada)")
plt.xlabel("Nombre de Especie")
plt.ylabel("Número de Imágenes")
plt.xticks(rotation=45, ha="right")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# Se encontraron 27 especies de la lista en el dataset:
# - aglaophenia: 524 imágenes
# - aplysina aerophoba: 1206 imágenes
# - chondrosia reniformis: 1592 imágenes
# - cliona celata: 517 imágenes
# - coscinasterias tenuispina: 770 imágenes
# - crambe crambe: 2884 imágenes
# - dysidea fragilis: 125 imágenes
# - eudendrium: 404 imágenes
# - ircinia variabilis: 289 imágenes
# - pecten jacobaeus: 56 imágenes
# - reptadeonella violacea: 140 imágenes
# - schizobrachiella sanguinea: 302 imágenes
# - arbacia lixula: 1928 imágenes
# - caloria quatrefagesi: 342 imágenes
# - conger conger: 306 imágenes
# - cratena peregrina: 2369 imágenes
# - flabellina affinis: 900 imágenes
# - gobius cruentatus: 833 imágenes
# - hexaplex trunculus: 1008 imágenes
# - nemesignis banyulensis: 338 imágenes
# - parablennius gattorugine: 1462 imágenes
# - parablennius pilicornis: 4746 imágenes
# - parablennius tentacularis: 204 imágenes
# - polycera quadrilineata: 289 imágenes
# - serranus cabrilla: 2748 imágenes
# - stenopus spinosus: 198 imágenes
# - stramonita haemastoma: 1630 imágenes
#
# No se encontraron 1 especies de la lista:
# - didemnum sp

# %%
# Buscar especies que contengan "didemnum" en el nombre científico o en species_guess
didemnum_df = df[
    (df['scientific_name'].str.lower().str.contains('didemnum', na=False)) |
    (df['species_guess'].str.lower().str.contains('didemnum', na=False))
]

# Contar cuántas instancias hay de cada especie
if len(didemnum_df) > 0:
    # Usar scientific_name, pero si es NaN usar species_guess
    didemnum_df['species_name'] = didemnum_df['scientific_name'].fillna(didemnum_df['species_guess'])
    species_counts = didemnum_df['species_name'].value_counts()
    
    # Mostrar el número total de instancias
    print(f"Se encontraron {len(didemnum_df)} instancias de especies con 'didemnum' en su nombre:")
    print(species_counts)
    
    # Crear histograma
    plt.figure(figsize=(12, 6))
    species_counts.plot(kind='bar', color='skyblue')
    plt.title('Número de Imágenes por Especies que contienen "didemnum"')
    plt.xlabel('Nombre de Especie')
    plt.ylabel('Número de Imágenes')
    plt.xticks(rotation=45, ha='right')
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()
else:
    print("No se encontraron especies con 'didemnum' en su nombre científico o species_guess.")
# Out:
# No se encontraron especies con 'didemnum' en su nombre científico o species_guess.

# %%
# Crear lista de posibles variantes del nombre
search_terms = ['didemnum lahillei', 'didemnum', 'didemnidae']

# Buscar en varias columnas para cualquier mención de las variantes
results = []
for term in search_terms:
    # Buscar en scientific_name, species_guess y cleaned_name con case insensitive
    matches = df[
        (df['scientific_name'].str.lower().str.contains(term, na=False)) |
        (df['species_guess'].str.lower().str.contains(term, na=False)) |
        (df['cleaned_name'].str.contains(term, na=False))
    ]
    results.append(matches)
    print(f"Encontradas {len(matches)} instancias conteniendo '{term}'")
    
# Combinar resultados y eliminar duplicados
all_results = pd.concat(results).drop_duplicates()

if len(all_results) > 0:
    print(f"\nSe encontraron {len(all_results)} instancias de especies relacionadas con Didemnum:")
    # Mostrar las especies encontradas agrupadas por nombre científico
    species_counts = all_results['scientific_name'].value_counts()
    print(species_counts)
    
    # Mostrar ejemplos de las especies encontradas
    print("\nEjemplos de las especies encontradas:")
    display(all_results[['id', 'scientific_name', 'species_guess', 'cleaned_name']].head(10))
else:
    print("No se encontraron especies relacionadas con Didemnum en el dataset.")
# Out:
# Encontradas 0 instancias conteniendo 'didemnum lahillei'
# Encontradas 0 instancias conteniendo 'didemnum'
# Encontradas 0 instancias conteniendo 'didemnidae'
# No se encontraron especies relacionadas con Didemnum en el dataset.
